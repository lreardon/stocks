# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from trading.strategy_evaluator import StrategyEvaluator

# %%
from trading.strategies.strategy_2 import strategy_2

s = StrategyEvaluator(strategy=strategy_2)
s.load_historical_for_ticker('SPY')

# %%
s.apply_strategy()
s.calculate_cumulative_returns()

# %%
s.plot_cumulative_returns()
